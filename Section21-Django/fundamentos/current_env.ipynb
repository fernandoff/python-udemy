# %%
import os
import django
from products.models import Product

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
os.chdir(r"C:\TRABALHO\Python\Curso\Section21-Django\fundamentos")
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'setup.settings')

django.setup()

product = Product()
product.name = 'Caneca'
product.price = 19.90
product.description = 'Caneca de cerâmica branca'
product.stock = 3

product.save()
print(product)
# Out:
# Product(
#   id=15,
#   name='Caneca',
#   description='Caneca de cerâmica branca',
#   price=19.9,
#   stock=3,
#   slug='',
#   banner='',
#   created_at='2025-12-17 17:04:59.715715+00:00'
# )
