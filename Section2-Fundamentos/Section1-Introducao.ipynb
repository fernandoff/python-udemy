# %% [markdown]
# Lição 1 Python

# %%
print("Lição 1 - Introdução ao Python")
print("Hello world!")
idade = 20
print("Idadeaaaaa:", idade)
valor_primario = 10
valor_secundario = 5
soma = valor_primario + valor_secundario
print("Soma:", soma)
print("Lição 2 - Tipos de Dados e Variáveis")
nome = "Maria"
altura = 1.65
estudante = True
# Out:
# Lição 1 - Introdução ao Python
# Hello world!
# Idadeaaaaa: 20
# Soma: 15
# Lição 2 - Tipos de Dados e Variáveis

# %%
print("Nome:", nome)
print("Altura:", altura)
print("Estudante:", estudante)
# Out:
# Nome: Maria
# Altura: 1.65
# Estudante: True
